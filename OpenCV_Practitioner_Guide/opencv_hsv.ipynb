# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/OpenCV_Practitioner_Guide_1/blob/main/opencv_hsv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# low_yellow = [220, 194, 4]
# high_yellow = [255, 214, 59]

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
src = cv2.imread('./bicycle.png', cv2.IMREAD_UNCHANGED)

# %%
src.shape
# Out:
# (1534, 2045, 4)

# %%
cv2_imshow(src)
# Out:
# <PIL.Image.Image image mode=RGBA size=2045x1534 at 0x7FABDBB66B90>

# %%
import numpy as np

# %%
low_yellow = np.array([0, 192, 0])
high_yellow = np.array([255, 255, 255])

# %%
src_rgb = cv2.cvtColor(src, cv2.COLOR_BGR2HSV)

# %%
mask = cv2.inRange(src_rgb, low_yellow, high_yellow)

# %%
src_result = cv2.bitwise_and(src, src, mask = mask)

# %%
src_result = cv2.resize(src_result, (0,0), fx=0.3, fy=0.3)

# %%
cv2_imshow(src_result)
# Out:
# <PIL.Image.Image image mode=RGBA size=614x460 at 0x7FABDAB03750>
