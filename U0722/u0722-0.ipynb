# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/Uniinfo-Machine-Vision/blob/main/U0722/u0722-0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow

# %%
src = cv2.imread('elephant2.png')

# %%
ele1 = src[120:330, 50:250]

# %%
ele2 = src[71:518, 254:869]

# %%
src.shape
# Out:
# (532, 946, 3)

# %%
cv2_imshow(ele2)
# Out:
# <PIL.Image.Image image mode=RGB size=615x447 at 0x7F4FBE135250>

# %%
cv2_imshow(src)
# Out:
# <PIL.Image.Image image mode=RGB size=946x532 at 0x7F4FC814E850>
