# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/Uniinfo-Machine-Vision/blob/main/U0708/3-1-count_transform.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
src = cv2.imread('./antivirus.jpg', cv2.COLOR_BGR2RGB)

# %%
cv2_imshow(src)
# Out:
# <PIL.Image.Image image mode=RGB size=600x450 at 0x7F748B3E3DD0>

# %%
import numpy as np

# %%
low_red = np.array([0, 123, 0])

high_red = np.array([255, 255, 255])

# %%
src_hsv = cv2.cvtColor(src, cv2.COLOR_BGR2HSV)

# %%
mask = cv2.inRange(src_hsv, low_red, high_red)

# %%
result_src = cv2.bitwise_and(src, src, mask = mask)

# %%
cv2_imshow(result_src)
# Out:
# <PIL.Image.Image image mode=RGB size=600x450 at 0x7F747AE54350>

# %%
_, image_thresh = cv2.threshold(mask, 0, 255, cv2.THRESH_BINARY, cv2.THRESH_OTSU)

# %%
cv2_imshow(image_thresh)
# Out:
# <PIL.Image.Image image mode=L size=600x450 at 0x7F747AE6A450>

# %%
blur = cv2.medianBlur(image_thresh, 13)

# %%
cv2_imshow(blur)
# Out:
# <PIL.Image.Image image mode=L size=600x450 at 0x7F74795ED6D0>

# %%
dist_transform = cv2.distanceTransform(blur,cv2.DIST_L2,3)
ret, isolate_image =  cv2.threshold(dist_transform, 0.5*dist_transform.max(),255,0)

# %%
dist_transform = cv2.distanceTransform(blur, cv2.DIST_L2, 3)

# %%
ret, isolate_image =cv2.threshold(dist_transform, 0.6*dist_transform.max(), 255, 0)

# %%
print(ret)
# Out:
# 21.36097412109375

# %%
cv2_imshow(isolate_image)
# Out:
# <PIL.Image.Image image mode=L size=600x450 at 0x7F747BEB6F90>
